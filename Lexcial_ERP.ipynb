# %% [markdown]
# <a href="https://colab.research.google.com/github/Emrose-1341/EEG-Data/blob/Task-Analysis/Lexcial_ERP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mode
from scipy.stats import norm as norm

# %%
directory = "C:/Users/emros/Downloads/Lexical Text Files/Lexical Text Files"
Lexical_ERPs= "Lexical_ERPs.xlsx"
file_path = f"{directory}/{Lexical_ERPs}"

# %%
lex_df = f"File path: {file_path}"

# %%
print(lex_df.head)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-573af52baca4> in <cell line: 1>()
# ----> 1 print(lex_df.head)
#
# AttributeError: 'str' object has no attribute 'head'

# %%
from google.colab import drive
drive.mount('/content/drive')
